# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

train_given=pd.read_csv('data/train.csv')
train=pd.read_csv('data/train.csv')

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train[train['Survived']==1]['Sex']
# Out:
# 1      female
# 2      female
# 3      female
# 8      female
# 9      female
# 10     female
# 11     female
# 15     female
# 17       male
# 19     female
# 21       male
# 22     female
# 23       male
# 25     female
# 28     female
# 31     female
# 32     female
# 36       male
# 39     female
# 43     female
# 44     female
# 47     female
# 52     female
# 53     female
# 55       male
# 56     female
# 58     female
# 61     female
# 65       male
# 66     female
#         ...
# 809    female
# 820    female
# 821      male
# 823    female
# 827      male
# 828      male
# 829    female
# 830    female
# 831      male
# 835    female
# 838      male
# 839      male
# 842    female
# 849    female
# 853    female
# 855    female
# 856    female
# 857      male
# 858    female
# 862    female
# 865    female
# 866    female
# 869      male
# 871    female
# 874    female
# 875    female
# 879    female
# 880    female
# 887    female
# 889      male
# ...

# %%
survived = train[train['Survived']==1]['Sex'].value_counts()
dead = train[train['Survived']==0]['Sex'].value_counts()
df = pd.DataFrame([survived,dead])
print(df)
df.index = ['Survived','Dead']
print(df)
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
#      female  male
# Sex     233   109
# Sex      81   468
#           female  male
# Survived     233   109
# Dead          81   468

# %%
fig = plt.figure(figsize=(10,4))
fig.add_subplot(121)
train.Survived[train['Sex'] == 'male'].value_counts().plot(kind='pie')
fig.add_subplot(122)
train.Survived[train['Sex'] == 'female'].value_counts().plot(kind='pie')

# %%
# from sklearn.preprocessing import LabelEncoder
# train['Sex'] = LabelEncoder().fit_transform(train['Sex'])

# %%
sex_mapping = {"male": 0, "female": 1}
train['Sex'] = train['Sex'].map(sex_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
print(train['Name'][0])
print(train['Name'][0].split(',')[1])
print(train['Name'][0].split(',')[1].split('.')[0])
print(train['Name'][0].split(',')[1].split('.')[0].strip())
# Out:
# Braund, Mr. Owen Harris
#  Mr. Owen Harris
#  Mr
# Mr

# %%
train['Name'] = train['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())
titles = train['Name'].unique()
titles
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
train1=train.copy()

# %%
train1['Age'].fillna(-1, inplace=True)
medians = dict()
for title in titles:
    median = train1.Age[(train1["Age"] != -1) & (train1['Name'] == title)].median()
    medians[title] = median
for index, row in train1.iterrows():
    if row['Age'] == -1:
        train1.loc[index, 'Age'] = medians[row['Name']]
train1.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    0  22.0      1      0
# 1            2         1       1   Mrs    1  38.0      1      0
# 2            3         1       3  Miss    1  26.0      0      0
# 3            4         1       1   Mrs    1  35.0      1      0
# 4            5         0       3    Mr    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
row
# Out:
# PassengerId       891
# Survived            0
# Pclass              3
# Name               Mr
# Sex                 0
# Age                32
# SibSp               0
# Parch               0
# Ticket         370376
# Fare             7.75
# Cabin             NaN
# Embarked            Q
# Name: 890, dtype: object

# %%
index
# Out:
# 890

# %%
train1.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001DD0F218678>

# %%
train1.head(10)
# Out:
#    PassengerId  Survived  Pclass    Name  Sex   Age  SibSp  Parch  \
# 0            1         0       3      Mr    0  22.0      1      0
# 1            2         1       1     Mrs    1  38.0      1      0
# 2            3         1       3    Miss    1  26.0      0      0
# 3            4         1       1     Mrs    1  35.0      1      0
# 4            5         0       3      Mr    0  35.0      0      0
# 5            6         0       3      Mr    0  30.0      0      0
# 6            7         0       1      Mr    0  54.0      0      0
# 7            8         0       3  Master    0   2.0      3      1
# 8            9         1       3     Mrs    1  27.0      0      2
# 9           10         1       2     Mrs    1  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
train2=train.copy()

# %%
train2["Age"].fillna(train2.groupby("Name")["Age"].transform("median"), inplace=True)

# %%
train2.head(10)
# Out:
#    PassengerId  Survived  Pclass    Name  Sex   Age  SibSp  Parch  \
# 0            1         0       3      Mr    0  22.0      1      0
# 1            2         1       1     Mrs    1  38.0      1      0
# 2            3         1       3    Miss    1  26.0      0      0
# 3            4         1       1     Mrs    1  35.0      1      0
# 4            5         0       3      Mr    0  35.0      0      0
# 5            6         0       3      Mr    0  30.0      0      0
# 6            7         0       1      Mr    0  54.0      0      0
# 7            8         0       3  Master    0   2.0      3      1
# 8            9         1       3     Mrs    1  27.0      0      2
# 9           10         1       2     Mrs    1  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass    Name  Sex   Age  SibSp  Parch  \
# 0            1         0       3      Mr    0  22.0      1      0
# 1            2         1       1     Mrs    1  38.0      1      0
# 2            3         1       3    Miss    1  26.0      0      0
# 3            4         1       1     Mrs    1  35.0      1      0
# 4            5         0       3      Mr    0  35.0      0      0
# 5            6         0       3      Mr    0   NaN      0      0
# 6            7         0       1      Mr    0  54.0      0      0
# 7            8         0       3  Master    0   2.0      3      1
# 8            9         1       3     Mrs    1  27.0      0      2
# 9           10         1       2     Mrs    1  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
train3=train.copy()

# %%
train3.groupby("Name")["Age"].transform("median")
# Out:
# 0      30.0
# 1      35.0
# 2      21.0
# 3      35.0
# 4      30.0
# 5      30.0
# 6      30.0
# 7       3.5
# 8      35.0
# 9      35.0
# 10     21.0
# 11     21.0
# 12     30.0
# 13     30.0
# 14     21.0
# 15     35.0
# 16      3.5
# 17     30.0
# 18     35.0
# 19     35.0
# 20     30.0
# 21     30.0
# 22     21.0
# 23     30.0
# 24     21.0
# 25     35.0
# 26     30.0
# 27     30.0
# 28     21.0
# 29     30.0
#        ...
# 861    30.0
# 862    35.0
# 863    21.0
# 864    30.0
# 865    35.0
# 866    21.0
# 867    30.0
# 868    30.0
# 869     3.5
# 870    30.0
# 871    35.0
# 872    30.0
# 873    30.0
# 874    35.0
# 875    21.0
# 876    30.0
# 877    30.0
# 878    30.0
# 879    35.0
# 880    35.0
# 881    30.0
# 882    21.0
# 883    30.0
# 884    30.0
# 885    35.0
# 886    46.5
# 887    21.0
# 888    21.0
# 889    30.0
# 890    30.0
# Name: Age, Length: 891, dtype: float64

# %%
train=train1.copy()

# %%
import seaborn as sns
sns.set() #setting seaborn as default

facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,6))
i=1
for title in train['Name'].unique():
    fig.add_subplot(3, 6, i)
    plt.title('Title : {}'.format(title))
    train.Survived[train['Name'] == title].value_counts().plot(kind='pie')
    i += 1

# %%
replacement = {
'Don': 0,
'Rev': 0,
'Jonkheer': 0,
'Capt': 0,
'Mr': 1,
'Dr': 2,
'Col': 3,
'Major': 3,
'Master': 4,
'Miss': 5,
'Mrs': 6,
'Mme': 7,
'Ms': 7,
'Mlle': 7,
'Sir': 7,
'Lady': 7,
'the Countess': 7}
train['Name'] = train['Name'].apply(lambda x: replacement[x])

# %%
from sklearn.preprocessing import StandardScaler
train['Name'] = StandardScaler().fit_transform(train['Name'].values.reshape(-1, 1))
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train['Age'] = StandardScaler().fit_transform(train['Age'].values.reshape(-1, 1))

# %%
train['Fare'].fillna(-1, inplace=True)
medians = dict()
for pclass in train['Pclass'].unique():
    median = train.Fare[(train["Fare"] != -1) & (train['Pclass'] == pclass)].median()
    medians[pclass] = median
for index, row in train.iterrows():
    if row['Fare'] == -1:
        train.loc[index, 'Fare'] = medians[row['Pclass']]
train['Fare'] = StandardScaler().fit_transform(train['Fare'].values.reshape(-1, 1))

# %%
fig = plt.figure(figsize=(15,4))
i=1
for pclass in train['Pclass'].unique():
    fig.add_subplot(1, 3, i)
    plt.title('Class : {}'.format(pclass))
    train.Survived[train['Pclass'] == pclass].value_counts().plot(kind='pie')
    i += 1
train['Pclass'] = StandardScaler().fit_transform(train['Pclass'].values.reshape(-1, 1))
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train.head(10)
# Out:
#    PassengerId  Survived    Pclass      Name  Sex       Age  SibSp  Parch  \
# 0            1         0  0.827377 -0.797294    0 -0.557420      1      0
# 1            2         1 -1.566107  1.537975    1  0.649410      1      0
# 2            3         1  0.827377  1.070922    1 -0.255712      0      0
# 3            4         1 -1.566107  1.537975    1  0.423129      1      0
# 4            5         0  0.827377 -0.797294    0  0.423129      0      0
# 5            6         0  0.827377 -0.797294    0  0.045995      0      0
# 6            7         0 -1.566107 -0.797294    0  1.856240      0      0
# 7            8         0  0.827377  0.603868    0 -2.065957      3      1
# 8            9         1  0.827377  1.537975    1 -0.180285      0      2
# 9           10         1 -0.369365  1.537975    1 -1.160835      1      0
#
#              Ticket      Fare Cabin Embarked
# 0         A/5 21171 -0.502445   NaN        S
# 1          PC 17599  0.786845   C85        C
# ...

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
fig = plt.figure(figsize=(15,10))
i = 0
for fsize in train['FamilySize'].unique():
    fig.add_subplot(3, 4, i+1)
    plt.title('Family Size : {}'.format(fsize))
    train.Survived[train['FamilySize'] == fsize].value_counts().plot(kind='pie')
    i += 1

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 11.0)

# %%
train.head()
# Out:
#    PassengerId  Survived    Pclass      Name  Sex       Age  SibSp  Parch  \
# 0            1         0  0.827377 -0.797294    0 -0.557420      1      0
# 1            2         1 -1.566107  1.537975    1  0.649410      1      0
# 2            3         1  0.827377  1.070922    1 -0.255712      0      0
# 3            4         1 -1.566107  1.537975    1  0.423129      1      0
# 4            5         0  0.827377 -0.797294    0  0.423129      0      0
#
#              Ticket      Fare Cabin Embarked  FamilySize
# 0         A/5 21171 -0.502445   NaN        S           2
# 1          PC 17599  0.786845   C85        C           2
# 2  STON/O2. 3101282 -0.488854   NaN        S           1
# 3            113803  0.420730  C123        S           2
# 4            373450 -0.486337   NaN        S           1

# %%
replacement = {
11: 0,
8: 0,
6: 1,
5: 2,
7: 3,
1: 4,
3: 5,
2: 6,
4: 7
}
train['FamilySize'] = train['FamilySize'].apply(lambda x: replacement.get(x))
train['FamilySize'] = StandardScaler().fit_transform(train['FamilySize'].values.reshape(-1, 1))
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Embarked'].fillna('S', inplace=True)
fig = plt.figure(figsize=(15,4))
i = 1
for embarked in train['Embarked'].unique():
    fig.add_subplot(1, 3, i)
    plt.title('Embarked : {}'.format(embarked))
    train.Survived[train['Embarked'] == embarked].value_counts().plot(kind='pie')
    i += 1

# %%
replacement = {
'S': 0,
'Q': 1,
'C': 2
}
train['Embarked'] = train['Embarked'].apply(lambda x: replacement.get(x))
train['Embarked'] = StandardScaler().fit_transform(train['Embarked'].values.reshape(-1, 1))
train.head()['Embarked']
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 0   -0.585954
# 1    1.942303
# 2   -0.585954
# 3   -0.585954
# 4   -0.585954
# Name: Embarked, dtype: float64

# %%
train[~ train['Cabin'].isnull()]['Cabin']
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
#           ...
# 751           E121
# 759            B77
# 763        B96 B98
# 765            D11
# 772            E77
# 776            F38
# 779             B3
# 781            B20
# 782             D6
# 789        B82 B84
# 796            D17
# 802        B96 B98
# 806            A36
# 809             E8
# 815           B102
# 820            B69
# ...

# %%
train
# Out:
#      PassengerId  Survived    Pclass      Name  Sex       Age  SibSp  Parch  \
# 0              1         0  0.827377 -0.797294    0 -0.557420      1      0
# 1              2         1 -1.566107  1.537975    1  0.649410      1      0
# 2              3         1  0.827377  1.070922    1 -0.255712      0      0
# 3              4         1 -1.566107  1.537975    1  0.423129      1      0
# 4              5         0  0.827377 -0.797294    0  0.423129      0      0
# 5              6         0  0.827377 -0.797294    0  0.045995      0      0
# 6              7         0 -1.566107 -0.797294    0  1.856240      0      0
# 7              8         0  0.827377  0.603868    0 -2.065957      3      1
# 8              9         1  0.827377  1.537975    1 -0.180285      0      2
# 9             10         1 -0.369365  1.537975    1 -1.160835      1      0
# 10            11         1  0.827377  1.070922    1 -1.915103      1      1
# ...

# %%
train['Cabin'] = train['Cabin'].str[:1]
train['Cabin'].unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
fig = plt.figure(figsize=(15,12))
i = 1
for cabin in train['Cabin'].unique()[1:]:
    fig.add_subplot(3, 3, i)
    plt.title('Cabin : {}'.format(cabin))
    train.Survived[train['Cabin'] == cabin].value_counts().plot(kind='pie')
    i += 1

# %%
replacement = {
'T': 0,
'A': 1,
'G': 2,
'C': 3,
'F': 4,
'B': 5,
'E': 6,
'D': 7
}
train['Cabin'] = train['Cabin'].apply(lambda x: replacement.get(x))

# %%
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

# %%
train['Cabin'] = StandardScaler().fit_transform(train['Cabin'].values.reshape(-1, 1))
train.head()['Cabin']
# Out:
# 0   -0.356893
# 1   -1.409844
# 2   -0.356893
# 3   -1.409844
# 4   -0.356893
# Name: Cabin, dtype: float64

# %%
# from sklearn.model_selection import train_test_split
# survived = data['Survived']
# data.drop('Survived', axis=1, inplace=True)
# X_train, X_test, y_train, y_test = train_test_split(data, survived, test_size=0.2, random_state=42)

# %%
train.head()
# Out:
#    PassengerId  Survived    Pclass      Name  Sex       Age  SibSp  Parch  \
# 0            1         0  0.827377 -0.797294    0 -0.557420      1      0
# 1            2         1 -1.566107  1.537975    1  0.649410      1      0
# 2            3         1  0.827377  1.070922    1 -0.255712      0      0
# 3            4         1 -1.566107  1.537975    1  0.423129      1      0
# 4            5         0  0.827377 -0.797294    0  0.423129      0      0
#
#              Ticket      Fare     Cabin  Embarked  FamilySize
# 0         A/5 21171 -0.502445 -0.356893 -0.585954    1.306354
# 1          PC 17599  0.786845 -1.409844  1.942303    1.306354
# 2  STON/O2. 3101282 -0.488854 -0.356893 -0.585954   -0.320427
# 3            113803  0.420730 -1.409844 -0.585954    1.306354
# 4            373450 -0.486337 -0.356893 -0.585954   -0.320427

# %%
features_drop = ['Ticket', 'SibSp', 'Parch','PassengerId']
train = train.drop(features_drop, axis=1)
train_data=train.drop("Survived",axis=1)

# %%
target=train['Survived']

# %%
train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
train_data.head()
# Out:
#      Pclass      Name  Sex       Age      Fare     Cabin  Embarked  FamilySize
# 0  0.827377 -0.797294    0 -0.557420 -0.502445 -0.356893 -0.585954    1.306354
# 1 -1.566107  1.537975    1  0.649410  0.786845 -1.409844  1.942303    1.306354
# 2  0.827377  1.070922    1 -0.255712 -0.488854 -0.356893 -0.585954   -0.320427
# 3 -1.566107  1.537975    1  0.423129  0.420730 -1.409844 -0.585954    1.306354
# 4  0.827377 -0.797294    0  0.423129 -0.486337 -0.356893 -0.585954   -0.320427

# %%
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.84444444 0.80898876 0.84269663 0.79775281 0.84269663 0.78651685
#  0.78651685 0.80898876 0.80898876 0.82022472]

# %%
round(np.mean(score)*100, 2)
# Out:
# 81.48

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)
# Out:
# [0.77777778 0.7752809  0.76404494 0.78651685 0.79775281 0.82022472
#  0.75280899 0.75280899 0.75280899 0.78651685]
# 77.67

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.81111111 0.86516854 0.80898876 0.78651685 0.82022472 0.82022472
#  0.82022472 0.79775281 0.76404494 0.82022472]

# %%
round(np.mean(score)*100, 2)
# Out:
# 81.14

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)
# Out:
# [0.81111111 0.80898876 0.79775281 0.73033708 0.74157303 0.78651685
#  0.7752809  0.82022472 0.80898876 0.80898876]
# 78.9

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)
# Out:
# [0.83333333 0.82022472 0.82022472 0.82022472 0.80898876 0.82022472
#  0.82022472 0.80898876 0.82022472 0.86516854]
# 82.38

# %%
test=pd.read_csv('data/test.csv')

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             85
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sex_mapping = {"male": 0, "female": 1}
test['Sex'] = test['Sex'].map(sex_mapping)

# %%
test['Name'] = test['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())
replacement = {
'Don': 0,
'Dona':0,
'Rev': 0,
'Jonkheer': 0,
'Capt': 0,
'Mr': 1,
'Dr': 2,
'Col': 3,
'Major': 3,
'Master': 4,
'Miss': 5,
'Mrs': 6,
'Mme': 7,
'Ms': 7,
'Mlle': 7,
'Sir': 7,
'Lady': 7,
'the Countess': 7}
test['Name'] = test['Name'].apply(lambda x: replacement[x])
test['Name'] = StandardScaler().fit_transform(test['Name'].values.reshape(-1, 1))
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
replacement = {
'S': 0,
'Q': 1,
'C': 2
}
test['Embarked'] = test['Embarked'].apply(lambda x: replacement.get(x))
test['Embarked'] = StandardScaler().fit_transform(test['Embarked'].values.reshape(-1, 1))
test.head()['Embarked']
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 0    0.470915
# 1   -0.700767
# 2    0.470915
# 3   -0.700767
# 4   -0.700767
# Name: Embarked, dtype: float64

# %%
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test['Fare'] = StandardScaler().fit_transform(test['Fare'].values.reshape(-1, 1))

# %%
test["Age"].fillna(test.groupby("Name")["Age"].transform("median"), inplace=True)
test['Age'] = StandardScaler().fit_transform(test['Age'].values.reshape(-1, 1))

# %%
test['Pclass'] = StandardScaler().fit_transform(test['Pclass'].values.reshape(-1, 1))
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1
replacement = {
11: 0,
8: 0,
9: 0,
10: 0,
12: 0,
6: 1,
5: 2,
7: 3,
1: 4,
3: 5,
2: 6,
4: 7
}
test['FamilySize'] = test['FamilySize'].apply(lambda x: replacement.get(x))
test['FamilySize'] = StandardScaler().fit_transform(test['FamilySize'].values.reshape(-1, 1))
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
test['Cabin'] = test['Cabin'].str[:1]
replacement = {
'T': 0,
'A': 1,
'G': 2,
'C': 3,
'F': 4,
'B': 5,
'E': 6,
'D': 7
}
test['Cabin'] = test['Cabin'].apply(lambda x: replacement.get(x))
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test['Cabin'] = StandardScaler().fit_transform(test['Cabin'].values.reshape(-1, 1))

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
test = test.drop(features_drop, axis=1)
test_data = test.drop("PassengerId", axis=1).copy()

# %%
test_data.head()
# Out:
#      Pclass      Name  Sex       Age      Fare    Cabin  Embarked  FamilySize
# 0  0.873482 -0.819966    0  0.372578 -0.497071  0.02825  0.470915   -0.411747
# 1  0.873482  1.486533    1  1.337733 -0.511934  0.02825 -0.700767    1.344478
# 2 -0.315819 -0.819966    0  2.495920 -0.463762  0.02825  0.470915   -0.411747
# 3  0.873482 -0.819966    0 -0.206516 -0.482135  0.02825 -0.700767   -0.411747
# 4  0.873482  1.486533    1 -0.592578 -0.417159  0.02825 -0.700767    0.466366

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
clf.fit(train_data, target)
prediction=clf.predict(test_data)

# %%
submission = pd.DataFrame({
"PassengerId": test["PassengerId"],
"Survived": prediction
})
submission.to_csv('submission.csv', index=False)

submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         0
